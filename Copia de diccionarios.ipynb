# %% [markdown]
# # Diccionarios

# %% [markdown]
# ## Crear Diccionarios

# %%
dicc = {  }

# %%
dicc2={ 'llave': 'valor1'}

# %%
dicc3 = {
    "primera_llave":1 ,
    "segunda_llave":2
}

# %%
diic_4={
    "paises": ["Mex","USA","NED",'BRA'],
    "ciudades": ["CDMX","CUERNAVACA","LIMA"]
}
diic_4
# Out:
# {'ciudades': ['CDMX', 'CUERNAVACA', 'LIMA'],
#  'paises': ['Mex', 'USA', 'NED', 'BRA']}

# %% [markdown]
# ## Acceder elementos de diccionarios

# %% [markdown]
# ## Modificar diccionarios

# %% [markdown]
# ### Agregar elementos a un diccionario

# %% [markdown]
# ### Quitar elementos de un diccionario

# %% [markdown]
# ### Modificar elementos de un diccionario

# %% [markdown]
# ## Caracteristicas de los diccionarios

# %% [markdown]
# ### No se admiten llaves duplicadas

# %% [markdown]
# ### Distintos tipos de elementos

# %% [markdown]
# ### Longitud y orden

# %% [markdown]
# ## Iterar sobre diccionarios
