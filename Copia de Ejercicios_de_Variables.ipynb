# %% [markdown]
# Escribir un programa que muestre por pantalla la cadena ¡Hola Mundo!.

# %%
print( "Hola Mundo" )
# Out:
# Hola Mundo

# %% [markdown]
# Escribir un programa que almacene la cadena ¡Hola Mundo! en una variable y luego muestre por pantalla el contenido de la variable.

# %%
var="¡Hola Mundo!"
var
# Out:
# '¡Hola Mundo!'

# %% [markdown]
# Escribir un programa que pregunte el nombre del usuario en la consola y después de que el usuario lo introduzca muestre por pantalla la cadena ¡Hola _______!, donde NOMBRE es el nombre que el usuario haya introducido.

# %%
nombre=input("¿Como te llamas? ")
print('¡Hola',nombre,'!')
# Out:
# ¿Como te llamas? Edgar
# ¡Hola Edgar !

# %% [markdown]
# Escribir un programa que muestre por pantalla el resultado de la siguiente operación aritmética
#  ![image.png](data:image/png;base64,...)

# %%
num=( (3+2)/ (2*5) )**2
num
# Out:
# 0.25

# %% [markdown]
# Escribir un programa que lea un entero positivo, N , introducido por el usuario y después muestre en pantalla la suma de todos los enteros desde 1 hasta N. La suma de los  primeros enteros positivos puede ser calculada de la siguiente forma:
#
# ![image.png](data:image/png;base64,...)

# %%
N=int(input( "Ingresar un numero entero positivo: "))
Suma=N*(N+1)/2
Suma
# Out:
# Ingresar un numero entero positivo: 23
# 276.0

# %% [markdown]
# Escribir un programa que pida al usuario su peso (en kg) y estatura (en metros), calcule el índice de masa corporal y lo almacene en una variable, y muestre por pantalla la frase Tu índice de masa corporal es IMC donde IMC es el índice de masa corporal calculado redondeado con dos decimales.
#
# ![image.png](data:image/png;base64,...)

# %%
Peso=float( input( "Ingresar su peso en kilogramos: " ))
Altura=float( input( "Ingresar su altura en metros: " ))
IMC= Peso/(Altura**2)
IMC=round(IMC,2)
print(" Tu índice de masa corporal",IMC)
# Out:
# Ingresar su peso en kilogramos: 324
# Ingresar su altura en metros: 1.8
#  Tu índice de masa corporal 100.0
